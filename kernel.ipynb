# %%
conda install -c conda-forge cvxopt
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Isaiah\anaconda3
#
#   added / updated specs:
#     - cvxopt
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.8.3                |   py37hc8dfbb8_1         3.1 MB  conda-forge
#     cvxopt-1.2.5               |   py37hae2733a_1         962 KB  conda-forge
#     dsdp-5.8                   |    h6a76313_1203         213 KB  conda-forge
#     fftw-3.3.8                 |nompi_h24e91a8_1111         753 KB  conda-forge
#     glpk-4.65                  |    h2fa13f4_1002         3.2 MB  conda-forge
#     gsl-2.6                    |       h86b8168_0         1.6 MB  conda-forge
#     libblas-3.8.0              |           15_mkl         3.5 MB  conda-forge
#     libcblas-3.8.0             |           15_mkl         3.5 MB  conda-forge
#     liblapack-3.8.0            |           15_mkl         3.5 MB  conda-forge
#     python_abi-3.7             |          1_cp37m           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        20.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   cvxopt             conda-forge/win-64::cvxopt-1.2.5-py37hae2733a_1
#   dsdp               conda-forge/win-64::dsdp-5.8-h6a76313_1203
#   fftw               conda-forge/win-64::fftw-3.3.8-nompi_h24e91a8_1111
#   glpk               conda-forge/win-64::glpk-4.65-h2fa13f4_1002
#   gsl                conda-forge/win-64::gsl-2.6-h86b8168_0
#   libblas            conda-forge/win-64::libblas-3.8.0-15_mkl
#   libcblas           conda-forge/win-64::libcblas-3.8.0-15_mkl
#   liblapack          conda-forge/win-64::liblapack-3.8.0-15_mkl
#   python_abi         conda-forge/win-64::python_abi-3.7-1_cp37m
#
# The following packages will be UPDATED:
#
#   conda                       pkgs/main::conda-4.8.2-py37_0 --> conda-forge::conda-4.8.3-py37hc8dfbb8_1
#
#
#
# Downloading and Extracting Packages
#
# libcblas-3.8.0       | 3.5 MB    |            |   0%
# libcblas-3.8.0       | 3.5 MB    |            |   0%
# libcblas-3.8.0       | 3.5 MB    |            |   1%
# libcblas-3.8.0       | 3.5 MB    | 1          |   1%
# libcblas-3.8.0       | 3.5 MB    | 1          |   2%
# libcblas-3.8.0       | 3.5 MB    | 2          |   2%
# libcblas-3.8.0       | 3.5 MB    | 2          |   3%
# libcblas-3.8.0       | 3.5 MB    | 3          |   4%
# libcblas-3.8.0       | 3.5 MB    | 4          |   5%
# libcblas-3.8.0       | 3.5 MB    | 5          |   6%
# libcblas-3.8.0       | 3.5 MB    | 7          |   7%
# libcblas-3.8.0       | 3.5 MB    | 7          |   8%
# libcblas-3.8.0       | 3.5 MB    | 9          |   9%
# libcblas-3.8.0       | 3.5 MB    | #          |  11%
# libcblas-3.8.0       | 3.5 MB    | #1         |  12%
# libcblas-3.8.0       | 3.5 MB    | #3         |  14%
# libcblas-3.8.0       | 3.5 MB    | #4         |  15%
# libcblas-3.8.0       | 3.5 MB    | #6         |  16%
# libcblas-3.8.0       | 3.5 MB    | #8         |  18%
# libcblas-3.8.0       | 3.5 MB    | #9         |  19%
# libcblas-3.8.0       | 3.5 MB    | ##         |  21%
# libcblas-3.8.0       | 3.5 MB    | ##2        |  22%
# libcblas-3.8.0       | 3.5 MB    | ##4        |  24%
# libcblas-3.8.0       | 3.5 MB    | ##5        |  26%
# libcblas-3.8.0       | 3.5 MB    | ##7        |  28%
# libcblas-3.8.0       | 3.5 MB    | ##9        |  30%
# libcblas-3.8.0       | 3.5 MB    | ###1       |  31%
# libcblas-3.8.0       | 3.5 MB    | ###3       |  33%
# libcblas-3.8.0       | 3.5 MB    | ###5       |  35%
# libcblas-3.8.0       | 3.5 MB    | ###7       |  38%
# libcblas-3.8.0       | 3.5 MB    | ####       |  40%
# libcblas-3.8.0       | 3.5 MB    | ####2      |  42%
# libcblas-3.8.0       | 3.5 MB    | ####4      |  45%
# libcblas-3.8.0       | 3.5 MB    | ####7      |  48%
# libcblas-3.8.0       | 3.5 MB    | #####      |  50%
# libcblas-3.8.0       | 3.5 MB    | #####2     |  53%
# libcblas-3.8.0       | 3.5 MB    | #####5     |  55%
# libcblas-3.8.0       | 3.5 MB    | #####7     |  57%
# libcblas-3.8.0       | 3.5 MB    | #####9     |  59%
# libcblas-3.8.0       | 3.5 MB    | ######     |  61%
# libcblas-3.8.0       | 3.5 MB    | ######3    |  63%
# libcblas-3.8.0       | 3.5 MB    | ######6    |  67%
# libcblas-3.8.0       | 3.5 MB    | ######9    |  70%
# libcblas-3.8.0       | 3.5 MB    | #######2   |  72%
# libcblas-3.8.0       | 3.5 MB    | #######4   |  75%
# libcblas-3.8.0       | 3.5 MB    | #######7   |  78%
# libcblas-3.8.0       | 3.5 MB    | ########1  |  82%
# libcblas-3.8.0       | 3.5 MB    | ########4  |  85%
# libcblas-3.8.0       | 3.5 MB    | ########7  |  88%
# libcblas-3.8.0       | 3.5 MB    | #########  |  91%
# libcblas-3.8.0       | 3.5 MB    | #########4 |  95%
# libcblas-3.8.0       | 3.5 MB    | #########8 |  98%
# libcblas-3.8.0       | 3.5 MB    | ########## | 100%
#
# liblapack-3.8.0      | 3.5 MB    |            |   0%
# liblapack-3.8.0      | 3.5 MB    |            |   0%
# liblapack-3.8.0      | 3.5 MB    | 5          |   5%
# liblapack-3.8.0      | 3.5 MB    | 9          |   9%
# liblapack-3.8.0      | 3.5 MB    | #3         |  14%
# liblapack-3.8.0      | 3.5 MB    | #8         |  19%
# liblapack-3.8.0      | 3.5 MB    | ##4        |  25%
# liblapack-3.8.0      | 3.5 MB    | ##9        |  30%
# liblapack-3.8.0      | 3.5 MB    | ###4       |  35%
# liblapack-3.8.0      | 3.5 MB    | ####       |  40%
# liblapack-3.8.0      | 3.5 MB    | ####5      |  45%
# liblapack-3.8.0      | 3.5 MB    | #####      |  50%
# liblapack-3.8.0      | 3.5 MB    | #####7     |  58%
# liblapack-3.8.0      | 3.5 MB    | ######3    |  63%
# liblapack-3.8.0      | 3.5 MB    | ######9    |  69%
# liblapack-3.8.0      | 3.5 MB    | #######5   |  75%
# liblapack-3.8.0      | 3.5 MB    | ########1  |  82%
# liblapack-3.8.0      | 3.5 MB    | ########9  |  89%
# liblapack-3.8.0      | 3.5 MB    | #########8 |  98%
# liblapack-3.8.0      | 3.5 MB    | ########## | 100%
#
# dsdp-5.8             | 213 KB    |            |   0%
# dsdp-5.8             | 213 KB    | 7          |   8%
# dsdp-5.8             | 213 KB    | ########## | 100%
#
# python_abi-3.7       | 4 KB      |            |   0%
# python_abi-3.7       | 4 KB      | ########## | 100%
#
# fftw-3.3.8           | 753 KB    |            |   0%
# fftw-3.3.8           | 753 KB    | 2          |   2%
# fftw-3.3.8           | 753 KB    | 6          |   6%
# fftw-3.3.8           | 753 KB    | ###3       |  34%
# fftw-3.3.8           | 753 KB    | ###8       |  38%
# fftw-3.3.8           | 753 KB    | ####2      |  42%
# fftw-3.3.8           | 753 KB    | ####6      |  47%
# fftw-3.3.8           | 753 KB    | #####      |  51%
# fftw-3.3.8           | 753 KB    | ######3    |  64%
# fftw-3.3.8           | 753 KB    | ########   |  81%
# fftw-3.3.8           | 753 KB    | ########## | 100%
#
# libblas-3.8.0        | 3.5 MB    |            |   0%
# libblas-3.8.0        | 3.5 MB    |            |   0%
# libblas-3.8.0        | 3.5 MB    | 9          |  10%
# libblas-3.8.0        | 3.5 MB    | #6         |  17%
# libblas-3.8.0        | 3.5 MB    | ##2        |  23%
# libblas-3.8.0        | 3.5 MB    | ###2       |  32%
# libblas-3.8.0        | 3.5 MB    | ###9       |  40%
# libblas-3.8.0        | 3.5 MB    | ####6      |  47%
# libblas-3.8.0        | 3.5 MB    | #####4     |  54%
# libblas-3.8.0        | 3.5 MB    | ######1    |  61%
# libblas-3.8.0        | 3.5 MB    | ######7    |  67%
# libblas-3.8.0        | 3.5 MB    | #######3   |  73%
# libblas-3.8.0        | 3.5 MB    | ########1  |  82%
# libblas-3.8.0        | 3.5 MB    | ########6  |  87%
# libblas-3.8.0        | 3.5 MB    | #########1 |  92%
# libblas-3.8.0        | 3.5 MB    | ########## | 100%
#
# conda-4.8.3          | 3.1 MB    |            |   0%
# conda-4.8.3          | 3.1 MB    |            |   1%
# conda-4.8.3          | 3.1 MB    | 6          |   7%
# conda-4.8.3          | 3.1 MB    | #9         |  19%
# conda-4.8.3          | 3.1 MB    | ###3       |  33%
# conda-4.8.3          | 3.1 MB    | #####2     |  52%
# conda-4.8.3          | 3.1 MB    | ######2    |  62%
# conda-4.8.3          | 3.1 MB    | #######1   |  72%
# conda-4.8.3          | 3.1 MB    | ########5  |  86%
# conda-4.8.3          | 3.1 MB    | #########6 |  97%
# conda-4.8.3          | 3.1 MB    | ########## | 100%
#
# cvxopt-1.2.5         | 962 KB    |            |   0%
# cvxopt-1.2.5         | 962 KB    | 1          |   2%
# cvxopt-1.2.5         | 962 KB    | #8         |  18%
# cvxopt-1.2.5         | 962 KB    | ####1      |  42%
# cvxopt-1.2.5         | 962 KB    | ######1    |  62%
# cvxopt-1.2.5         | 962 KB    | #######4   |  75%
# cvxopt-1.2.5         | 962 KB    | ########## | 100%
#
# glpk-4.65            | 3.2 MB    |            |   0%
# glpk-4.65            | 3.2 MB    |            |   0%
# glpk-4.65            | 3.2 MB    | 3          |   4%
# glpk-4.65            | 3.2 MB    | 7          |   8%
# glpk-4.65            | 3.2 MB    | #2         |  12%
# glpk-4.65            | 3.2 MB    | #5         |  16%
# glpk-4.65            | 3.2 MB    | ##         |  20%
# glpk-4.65            | 3.2 MB    | ##5        |  26%
# glpk-4.65            | 3.2 MB    | ###        |  31%
# glpk-4.65            | 3.2 MB    | ###5       |  35%
# glpk-4.65            | 3.2 MB    | ####1      |  41%
# glpk-4.65            | 3.2 MB    | ####5      |  46%
# glpk-4.65            | 3.2 MB    | #####2     |  52%
# glpk-4.65            | 3.2 MB    | #####7     |  58%
# glpk-4.65            | 3.2 MB    | ######3    |  63%
# glpk-4.65            | 3.2 MB    | #######    |  70%
# glpk-4.65            | 3.2 MB    | #######5   |  76%
# glpk-4.65            | 3.2 MB    | ########2  |  83%
# glpk-4.65            | 3.2 MB    | #########2 |  93%
# glpk-4.65            | 3.2 MB    | ########## | 100%
#
# gsl-2.6              | 1.6 MB    |            |   0%
# gsl-2.6              | 1.6 MB    |            |   1%
# gsl-2.6              | 1.6 MB    | 1          |   2%
# gsl-2.6              | 1.6 MB    | 2          |   3%
# gsl-2.6              | 1.6 MB    | #4         |  14%
# gsl-2.6              | 1.6 MB    | ##2        |  23%
# gsl-2.6              | 1.6 MB    | ####4      |  45%
# gsl-2.6              | 1.6 MB    | #####8     |  58%
# gsl-2.6              | 1.6 MB    | #######6   |  77%
# gsl-2.6              | 1.6 MB    | #########3 |  94%
# gsl-2.6              | 1.6 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
import numpy as np
from numpy import linalg
import cvxopt
import cvxopt.solvers
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e50b58a978fd> in <module>
#       1 import numpy as np
#       2 from numpy import linalg
# ----> 3 import cvxopt
#       4 import cvxopt.solvers
#
# ModuleNotFoundError: No module named 'cvxopt'

# %%
def linear_kernel(x1, x2):
    return np.dot(x1, x2)

def polynomial_kernel(x, y, p=3):
    return (1 + np.dot(x, y)) ** p

def gaussian_kernel(x, y, sigma=5.0):
    return np.exp(-linalg.norm(x-y)**2 / (2 * (sigma ** 2)))

# %%
class SVM(object):

    def __init__(self, kernel=linear_kernel, C=None):
        self.kernel = kernel
        self.C = C
        if self.C is not None: self.C = float(self.C)

    def fit(self, X, y):
        n_samples, n_features = X.shape

        # Gram matrix
        K = np.zeros((n_samples, n_samples))
        for i in range(n_samples):
            for j in range(n_samples):
                K[i,j] = self.kernel(X[i], X[j])

        P = cvxopt.matrix(np.outer(y,y) * K)
        q = cvxopt.matrix(np.ones(n_samples) * -1)
        A = cvxopt.matrix(y, (1,n_samples))
        b = cvxopt.matrix(0.0)

        if self.C is None:
            G = cvxopt.matrix(np.diag(np.ones(n_samples) * -1))
            h = cvxopt.matrix(np.zeros(n_samples))
        else:
            tmp1 = np.diag(np.ones(n_samples) * -1)
            tmp2 = np.identity(n_samples)
            G = cvxopt.matrix(np.vstack((tmp1, tmp2)))
            tmp1 = np.zeros(n_samples)
            tmp2 = np.ones(n_samples) * self.C
            h = cvxopt.matrix(np.hstack((tmp1, tmp2)))

        # solve QP problem
        solution = cvxopt.solvers.qp(P, q, G, h, A, b)

        # Lagrange multipliers
        a = np.ravel(solution['x'])

        # Support vectors have non zero lagrange multipliers
        sv = a > 1e-5
        ind = np.arange(len(a))[sv]
        self.a = a[sv]
        self.sv = X[sv]
        self.sv_y = y[sv]
        print("%d support vectors out of %d points" % (len(self.a), n_samples))

        # Intercept
        self.b = 0
        for n in range(len(self.a)):
            self.b += self.sv_y[n]
            self.b -= np.sum(self.a * self.sv_y * K[ind[n],sv])
        self.b /= len(self.a)

        # Weight vector
        if self.kernel == linear_kernel:
            self.w = np.zeros(n_features)
            for n in range(len(self.a)):
                self.w += self.a[n] * self.sv_y[n] * self.sv[n]
        else:
            self.w = None

    def project(self, X):
        if self.w is not None:
            return np.dot(X, self.w) + self.b
        else:
            y_predict = np.zeros(len(X))
            for i in range(len(X)):
                s = 0
                for a, sv_y, sv in zip(self.a, self.sv_y, self.sv):
                    s += a * sv_y * self.kernel(X[i], sv)
                y_predict[i] = s
            return y_predict + self.b

    def predict(self, X):
        return np.sign(self.project(X))
